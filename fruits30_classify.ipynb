# %% [markdown]
# # 使用ResNet50对30种水果进行训练

# %%
# 建议在命令行中运行
# !python tools/train.py \
config/ResNet50_finetune.py \
--work-dir=./work_dirs
# Out:
# 06/08 17:13:23 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.9.15 (main, Nov  4 2022, 16:35:55) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     numpy_random_seed: 484986181
#     GPU 0: NVIDIA GeForce RTX 3070 Ti Laptop GPU
#     CUDA_HOME: D:\Software\anaconda3\envs\Z_pytorch
#     NVCC: Cuda compilation tools, release 11.7, V11.7.99
#     MSVC: 用于 x64 的 Microsoft (R) C/C++ 优化编译器 19.35.32216.1 版
#     GCC: n/a
#     PyTorch: 1.13.0
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 199711
#   - MSVC 192829337
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.7
# ...

# %% [markdown]
# # 使用训练好的模型进行推理

# %%
from mmpretrain import ImageClassificationInferencer
config = 'config/ResNet50_finetune.py'
checkpoint = 'work_dirs/best_accuracy/top1_epoch_179.pth'
inferencer = ImageClassificationInferencer(model=config, pretrained=checkpoint, device='cuda')
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# Loads checkpoint by local backend from path: work_dirs/best_accuracy/top1_epoch_179.pth

# %%
#对菠萝进行预测
image = 'https://th.bing.com/th/id/R.b83d4a4c56a1300a39971312989e4193?rik=P%2bbPO%2bD2kZef3Q&riu=http%3a%2f%2fpic.ntimg.cn%2ffile%2f20150407%2f20019086_093243681000_2.jpg&ehk=4h6Zez1Sp%2fnbUg%2b%2fpmfL4pk206wh%2bp1%2f9JPwv6PmO6E%3d&risl=&pid=ImgRaw&r=0'
result = inferencer(image)[0]
print(result['pred_class'])
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 菠萝

# %%
#对哈密瓜进行预测
image = 'https://th.bing.com/th/id/R.9b0a6df33c7c8f6a9e0f74bc23fd5718?rik=i48x0zojooxSRQ&pid=ImgRaw&r=0'
result = inferencer(image)[0]
print(result['pred_class'])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 哈密瓜

# %%
#对红苹果进行预测
image = 'https://scpic.chinaz.net/files/pic/pic9/201901/bpic10115.jpg'
result = inferencer(image)[0]
print(result['pred_class'])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 苹果-红

# %%
#对青苹果进行预测
image = 'https://th.bing.com/th/id/R.3bb0f7f122dd48a5aa6f46fbd9cec0d7?rik=I6gl2MGFRyWxrw&riu=http%3a%2f%2fup.jpgjpg.com%2fpic_360%2f37%2f00%2f73%2f3700737e9ac48fd4faf721a8a59aa7b7.jpg&ehk=ANNt2yqSHrjISAhkZXkI4nBXiAk95LSjfKrWq7ijOMM%3d&risl=&pid=ImgRaw&r=0'
result = inferencer(image)[0]
print(result['pred_class'])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 苹果-青

# %%
#对红葡萄进行预测
image = 'https://th.bing.com/th/id/OIP.04fnH44xKsbrY6r7rC3VkwHaFj?pid=ImgDet&rs=1'
result = inferencer(image)[0]
print(result['pred_class'])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 葡萄-红

# %%
#对白葡萄进行预测
image = 'https://th.bing.com/th/id/R.8387ccef5632f95798d0412e8c577b65?rik=sTA0d40uzmC3xQ&pid=ImgRaw&r=0'
result = inferencer(image)[0]
print(result['pred_class'])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 葡萄-白
